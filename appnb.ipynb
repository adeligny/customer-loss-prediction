# %% [markdown]
# Importation des librairies nécessaires

# %%
import pandas as pd
import matplotlib.pyplot as plt
import streamlit as st
import seaborn as sns
import geopandas as gpd
import numpy as np
import base64
import altair as alt

# %% [markdown]
# Mise en page avec insertion d'un gif (nécessitant l'import de base64) et utilisation de balises texte

# %%
st.markdown("<h1 style='text-align: center'>🔮 Bienvenue dans la tente mystique de Madame Irma... </h1>", unsafe_allow_html=True)

#affichage gif
gifPath = "C:\\Users\\anais\\Downloads\\crystal.gif"
file_ = open(gifPath, "rb")
contents = file_.read()
data_url = base64.b64encode(contents).decode("utf-8")
file_.close()

with st.columns(3)[1]:
    st.markdown(
    f'<img src="data:image/gif;base64,{data_url}" alt="gif">',
    unsafe_allow_html=True,
)
st.markdown("")
st.markdown("<div style='text-align: justify;'>Prêt à connaître ce que l'univers a prévu pour toi ? Réponds à mes questions, laisse les étoiles guider mes calculs, et je te dévoilerai la prime d'assurance auto qui te correspond, aussi unique que toi, mon cher voyageur ! 🌠</div>", unsafe_allow_html=True)
st.markdown("")
# Out:
# 2024-12-16 02:16:07.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# Formulaire à remplir par l'utilisateur pour le calcul de la prime d'assurance fictive

# %%
prenom = st.text_input("Comment t'appelles-tu ?")
if prenom:
    st.write(f"Aaahhhh comme c'est magnifique ! Bonjour, {prenom} !")


age = st.number_input("Quel âge as-tu ?")
if age:
    st.write(f"{age} ans ?! Tu es si jeune.")

nb_sinistres = st.number_input("Combien de sinistres as-tu eu ?")

genre = st.selectbox(
    "Quel est ton genre ?",
    ("Homme", "Femme", "Non-binaire"),
)

regime = st.selectbox(
    "Quel est ton régime alimentaire ?",
    ("Flexitarien", "Omnivore", "Pescetarien", "Végétalien", "Végétarien"),
)

region = st.selectbox(
    "Dans quelle région habites-tu ?",
("Auvergne-Rhône-Alpes",
"Bourgogne-Franche-Comté",
"Bretagne",
"Centre-Val de Loire",
"Corse",
"Grand Est",
"Hauts-de-France",
"Ile-de-France",
"Normandie",
"Nouvelle-Aquitaine",
"Occitanie",
"Pays de la Loire",
"Provence Alpes Côte d’Azur"),
)

fumeur = st.checkbox("Coche cette case si tu fumes.")
alcool = st.checkbox("Coche cette case si tu bois.")
enfant = st.checkbox("Coche cette case si tu as des enfants.")
telephone = st.checkbox("Coche cette case si tu utilises ton téléphone au volant.")
nuit = st.checkbox("Coche cette case si tu conduis la nuit.")
animal = st.checkbox("Coche cette case si tu as un animal de compagnie.")
jeu_course = st.checkbox("Coche cette case si tu joues à des jeux vidéo de course automobile.")
relaxation = st.checkbox("Coche cette case si tu pratiques la relaxation.")
gps = st.checkbox("Coche cette case si tu utilises le GPS.")

type_musique = st.selectbox(
    "Quel type de musique écoutes-tu ?",
    ("Calme", "Excitante"),
)

type_route = st.selectbox(
    "Sur quel type de route roules-tu en majorité ?",
    ("Urbain", "Autoroute", "Rural"),
)

carburant = st.selectbox(
    "Quel type de carburant utilises-tu ?",
    ("Essence", "Diesel", "Hybride", "Électrique"),
)

voiture = st.selectbox(
    "Quel est la marque de ta voiture ?",
    ("Toyota", "Renault", "Peugeot", "BMW", "Volkswagen"),
)

salaire = st.number_input("Quel est ton salaire ?")

anciennete = st.number_input("Depuis combien d'années as-tu ton permis ?")

musique = st.selectbox(
    "Quel genre de musique écoutes-tu ?",
    ("Classique", "Rock", "Pop", "Jazz", "Hip-hop"),
)

profession = st.selectbox(
    "Quel est ta profession ?",
    ("Ingénieur", "Médecin", "Professeur", "Commercial", "Artisan"),
)

modele_vehicule = st.selectbox(
    "Quel est ton modèle de véhicule ?",
    ("Yaris", "Clio", "308", "Golf", "Série 3"),
)
# Out:
# 2024-12-16 02:16:07.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# Récapitulatif des informations récupérées

# %%
if st.button("Enregistrer les informations"):
    utilisateur = {"Prénom": prenom, "Âge": age, "Genre": genre, "Régime alimentaire":regime, "Région":region, "Fumeur":fumeur,
                   "Modèle de véhicule":modele_vehicule, "Profession":profession, "Musique":musique, "Ancienneté du permis":anciennete,
                   "Salaire":salaire,"Marque de la voiture":voiture,"Type de carburant":carburant,"Type de route emprunté":type_route,
                   "Type de musique":type_musique, "Alcool":alcool, "Enfant":enfant, "Téléphone":telephone,
                   "Conduite de nuit":nuit, "Animal":animal, "Jeu de course":jeu_course,"Pratique de la relaxation":relaxation,
                   "Utilisation du GPS":gps, "Nombre de sinistres":nb_sinistres}
    
    st.success("Informations enregistrées avec succès !")
    
    # Afficher les données sauvegardées
    st.write("Si j'ai bien compris, tu as saisi les informations suivantes :")
    st.write(utilisateur)
# Out:
# 2024-12-16 02:16:07.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# Calcul de la prime d'asssurance à l'aide des données récupérées précédemment

# %%
st.markdown("<div style='text-align: justify;'>Très bien, laisse-moi voir ça... Hum... Oui, oui... Je ressens une énergie spéciale... Attends... Voilà, j’ai le chiffre ! Ta prime est prête ! 💥</div>", unsafe_allow_html=True)

st.text(" ")
# Prédiction de la prime
if st.button("Voir le montant de la prime d'assurance"):
    
    prime_de_base = 300  # Prime de base en euros
    prime_estimee = (
            prime_de_base +
            age * 0.5 +
            nb_sinistres * 100 +
            (150 if fumeur == "true" else 0) +
            (200 if alcool == "true" else 0) +
            (50 if nuit == "true" else 0) +
            (200 if telephone == "true" else 0)+
            (100 if animal == "true" else 0)+
            (100 if jeu_course == "false" else 0)+
            (100 if regime == "Omnivore" else 0)
        )

    st.write(f"### Prime d'assurance estimée : {prime_estimee:.2f} €")
# Out:
# 2024-12-16 02:16:07.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# Lecture et affichage de l'en-tête du fichier de données fictives généré avec le fichier donnees.py

# %%
df = pd.read_csv("resultats.csv")
print(df.head())
# Out:
#      Client  Nombre_de_sinistres  Prime Régime_alimentaire        Genre  \
# 0  Client_1                    5    595        Pescetarien        Femme
# 1  Client_2                    4    799           Omnivore        Femme
# 2  Client_3                    1    706         Végétarien        Femme
# 3  Client_4                    1    625        Flexitarien        Homme
# 4  Client_5                    0    322        Flexitarien  Non-binaire
#
#     Région_d_habitation  Fumeur  Enfants  Alcool  Salaire  ...  \
# 0  Auvergne-Rhône-Alpes    True    False   False    47789  ...
# 1         Île-de-France    True    False    True    76281  ...
# 2         Île-de-France   False     True    True    86853  ...
# 3         Île-de-France   False    False   False    76447  ...
# 4             Occitanie    True     True    True    35444  ...
#
#    Utilisation_téléphone  Profession Modèle_de_véhicule  Kilométrage_annuel  \
# 0                  False  Commercial               Golf               15380
# 1                  False  Professeur                308                7177
# 2                  False   Ingénieur              Yaris               25121
# 3                  False  Commercial              Yaris               28896
# 4                  False  Professeur              Yaris               10141
#
#    Genre_de_musique_préféré Animal_de_compagnie Utilisation_GPS  \
# 0                   Hip-hop               False           False
# 1                      Rock               False            True
# 2                 Classique                True           False
# 3                       Pop                True           False
# 4                      Rock               False           False
#
#    Jeux_video_courses  Pratique_relaxation Habitudes_de_lecture
# 0               False                 True            Fantaisie
# 1                True                 True           Historique
# 2               False                False            Fantaisie
# 3                True                False             Thriller
# 4               False                False           Historique
#
# [5 rows x 28 columns]

# %% [markdown]
# Partie statistiques descriptives (analyse de l'impact des variables explicatives sur le nombre de sinistres)
#
# #1 Utilisation de la variable Genre

# %%
st.write("# Statistiques descriptives")

accidents_par_genre = df.groupby('Genre')['Nombre_de_sinistres'].sum().reset_index()

# Afficher le tableau des sinistres par région
st.write("#### Nombre de sinistres par genre")
st.dataframe(accidents_par_genre.sort_values(by='Nombre_de_sinistres', ascending=False))

# Supposons que 'Genre' et 'Nombre d\'accidents' soient les colonnes pertinentes
genres = accidents_par_genre['Genre']
n_sinistres = accidents_par_genre['Nombre_de_sinistres']

# Calcul des pourcentages
pourcentages = (n_sinistres / n_sinistres.sum()) * 100

# Création du donut chart
fig, ax = plt.subplots(figsize=(10, 8))
ax.pie(pourcentages, labels=genres, autopct='%1.1f%%', startangle=100, wedgeprops={'width': 0.3})

# Afficher le graphique dans Streamlit
st.pyplot(fig)
# Out:
# 2024-12-16 02:16:07.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #2 Utilisation de la variable Région

# %%
sinistres_par_region = df.groupby('Région_d_habitation')['Nombre_de_sinistres'].sum().reset_index()

 # Afficher le tableau des sinistres par région
st.write("#### Nombre de sinistres par région")
st.dataframe(sinistres_par_region.sort_values(by='Nombre_de_sinistres', ascending=False))

    # Charger une carte des régions de France (GeoJSON)
france_regions = gpd.read_file("https://france-geojson.gregoiredavid.fr/repo/regions.geojson")

    # Fusionner les données avec la carte
france_regions = france_regions.merge(sinistres_par_region, left_on='nom', right_on='Région_d_habitation', how='left')

    # Remplir les régions sans données avec 0 sinistre
france_regions['Nombre_de_sinistres'] = france_regions['Nombre_de_sinistres'].fillna(0)

    # Créer une carte avec Geopandas
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
france_regions.plot(column='Nombre_de_sinistres', cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
ax.set_xlim([-5.0, 10])  # Ajuster les limites longitude
ax.set_ylim([41.0, 51.5])  # Ajuster les limites latitude

    # Afficher la carte dans Streamlit
st.pyplot(fig)
# Out:
# 2024-12-16 02:16:07.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:07.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:08.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:08.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:08.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #3 Création d'une Heatmap

# %%
st.write("#### Matrice des corrélations")

# Sélectionner les colonnes pertinentes : variables et le nombre de sinistres
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()

# Calcul des corrélations
correlation_matrix = df[numerical_cols].corr()

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
st.pyplot(plt)

st.markdown(
    """
    - Les valeurs proches de 1 indiquent une forte corrélation positive.
    - Les valeurs proches de -1 indiquent une forte corrélation négative.
    - Les valeurs proches de 0 indiquent peu ou pas de corrélation.
    """
)
# Out:
# 2024-12-16 02:16:08.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:08.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:08.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:08.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:08.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #4 Utilisation de la variable booléenne sur les jeux de course

# %%
st.write("#### Nombre de sinistres selon la pratique des jeux vidéo de course")
# Colonnes pertinentes : Nombre de sinistres et "joue_t-il_a_des_jeux_vidéo_de_course"
sinistres = df['Nombre_de_sinistres']
jeux_cour = df['Jeux_video_courses']


somme_sinistres_jeu = df.groupby("Jeux_video_courses")["Nombre_de_sinistres"].sum()
st.write(somme_sinistres_jeu)

plt.figure(figsize=(8, 6))
somme_sinistres_jeu.plot(kind='bar', color=['blue', 'orange'])
plt.ylabel('Somme des sinistres')
st.pyplot(plt)
# Out:
# 2024-12-16 02:16:09.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #5 Utilisation de la variable du type de musique écouté

# %%
st.write("#### Nombre de sinistres selon le type de musique écouté")
# Colonnes pertinentes : Nombre de sinistres et "joue_t-il_a_des_jeux_vidéo_de_course"
sinistres = df['Nombre_de_sinistres']
musique = df['Musique_calme_ou_excitante']


somme_sinistres_musique = df.groupby("Musique_calme_ou_excitante")["Nombre_de_sinistres"].sum()
st.write(somme_sinistres_musique)

plt.figure(figsize=(8, 6))
somme_sinistres_musique.plot(kind='bar', color=['green', 'yellow'])
plt.ylabel('Somme des sinistres')
st.pyplot(plt)
# Out:
# 2024-12-16 02:16:09.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #6 Utilisation de la variable régime alimentaire

# %%
st.write("#### Nombre de sinistres selon le régime alimentaire")

moyenne_sinistres_regime = df.groupby("Régime_alimentaire")["Nombre_de_sinistres"].mean()
st.write(moyenne_sinistres_regime)

# Compter le nombre de sinistres par régime alimentaire
somme_sinistres_regime = df.groupby("Régime_alimentaire")["Nombre_de_sinistres"].sum().reset_index()
st.write(somme_sinistres_regime)

plt.figure(figsize=(8, 6))
sns.barplot(x="Régime_alimentaire", y="Nombre_de_sinistres", data=somme_sinistres_regime)
plt.title("Nombre de sinistres par régime alimentaire")
plt.xlabel("Régime Alimentaire")
plt.ylabel("Nombre de Sinistres")
plt.show()

#Affichage Streamlit
fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="Régime_alimentaire", y="Nombre_de_sinistres", data=somme_sinistres_regime, ax=ax)
ax.set_xlabel("Régime Alimentaire")
ax.set_ylabel("Nombre de Sinistres")

# Afficher le graphique dans Streamlit
st.pyplot(fig)
# Out:
# 2024-12-16 02:16:09.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:09.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:10.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# #7 Graphiques interactifs

# %%
st.write("#### Distribution des données")

#graphique interactif

# Sélection de la variable explicative
variable = st.selectbox(
    "Choisissez une variable à explorer",
    options=['Alcool', 'Fumeur', 'Enfants', 'Animal_de_compagnie', 'Habitudes_de_lecture','Genre_de_musique_préféré', 'Type_de_carburant']
)

# Agrégation des données pour créer le graphique
agg_data = df.groupby(variable)['Nombre_de_sinistres'].mean().reset_index()

# Création du graphique avec Altair
chart = alt.Chart(agg_data).mark_bar().encode(
    x=alt.X(variable, title=variable),
    y=alt.Y('Nombre_de_sinistres', title='Moyenne des sinistres'),
    color=alt.Color(variable, legend=None)
).properties(
    title=f"Relation entre {variable} et le nombre de sinistres",
    width=600,
    height=400
)

# Affichage du graphique
st.altair_chart(chart)

# Filtres interactifs
revenu_min, revenu_max = st.slider(
    "Filtrer par revenu annuel",
    min_value=int(df['Salaire'].min()),
    max_value=int(df['Salaire'].max()),
    value=(30000, 80000)  # Valeur par défaut
)

age_min, age_max = st.slider(
    "Filtrer par âge",
    min_value=int(df['Âge'].min()),
    max_value=int(df['Âge'].max()),
    value=(25, 60)  # Valeur par défaut
)

# Application des filtres
filtered_data = df[(df['Salaire'] >= revenu_min) & (df['Salaire'] <= revenu_max)]
filtered_data = filtered_data[(filtered_data['Âge'] >= age_min) & (filtered_data['Âge'] <= age_max)]

# Création du graphique
chart = alt.Chart(filtered_data).mark_circle(size=60).encode(
    x='Salaire',
    y='Nombre_de_sinistres',
    color='Âge',
    tooltip=['Salaire', 'Nombre_de_sinistres', 'Âge']
).properties(
    width=700,
    height=400
)

# Affichage du graphique
st.altair_chart(chart)

# Ajout d'un filtre avec un slider
anciennete_min, anciennete_max = st.slider(
    "Sélectionnez la plage d'ancienneté du permis (en années)",
    min_value=int(df['Ancienneté_du_permis'].min()),
    max_value=int(df['Ancienneté_du_permis'].max()),
    value=(5, 30)  # Plage par défaut
)

# Filtrage des données en fonction de l'ancienneté
filtered_data = df[(df['Ancienneté_du_permis'] >= anciennete_min) & 
                     (df['Ancienneté_du_permis'] <= anciennete_max)]

# Calcul de la moyenne des sinistres par ancienneté
agg_data = filtered_data.groupby('Ancienneté_du_permis')['Nombre_de_sinistres'].mean().reset_index()

# Création du graphique avec Altair
chart = alt.Chart(agg_data).mark_line(point=True).encode(
    x=alt.X('Ancienneté_du_permis', title='Ancienneté_du_permis'),
    y=alt.Y('Nombre_de_sinistres', title='Moyenne des sinistres'),
    tooltip=['Ancienneté_du_permis', 'Nombre_de_sinistres']
).properties(
    title="Relation entre ancienneté du permis et nombre de sinistres",
    width=700,
    height=400
)

# Affichage du graphique dans Streamlit
st.altair_chart(chart)
# Out:
# 2024-12-16 02:16:11.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-16 02:16:11.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
